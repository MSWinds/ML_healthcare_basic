# %%
import numpy as np

# %%
import pandas as pd

# %%
df = pd.read_csv("listings.csv")

# %%
df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
df
# Out:
#              id                                               name    host_id  \
# 0          2015   Berlin-Mitte Value! Quiet courtyard/very central       2217
# 1          2695                 Prenzlauer Berg close to Mauerpark       2986
# 2          3176                    Fabulous Flat in great Location       3718
# 3          3309                  BerlinSpot Schöneberg near KaDeWe       4108
# 4          7071                   BrightRoom with sunny greenview!      17391
# ...         ...                                                ...        ...
# 22547  29856708       Cozy Apartment right in the center of Berlin   87555909
# 22548  29857108             Altbau/ Schöneberger Kiez / Schlafsofa   67537363
# 22549  29864272   Artists loft with garden in the center of Berlin    3146923
# 22550  29866805              Room for two with private shower / WC   36961901
# 22551  29867352  Sunny, modern and cozy flat in Berlin Neukölln :)  177464875
#
# ...

# %%
df.head()
# Out:
#      id                                              name  host_id host_name  \
# 0  2015  Berlin-Mitte Value! Quiet courtyard/very central     2217       Ian
# 1  2695                Prenzlauer Berg close to Mauerpark     2986   Michael
# 2  3176                   Fabulous Flat in great Location     3718    Britta
# 3  3309                 BerlinSpot Schöneberg near KaDeWe     4108      Jana
# 4  7071                  BrightRoom with sunny greenview!    17391    Bright
#
#       neighbourhood_group             neighbourhood   latitude  longitude  \
# 0                   Mitte           Brunnenstr. Süd  52.534537  13.402557
# 1                  Pankow  Prenzlauer Berg Nordwest  52.548513  13.404553
# 2                  Pankow   Prenzlauer Berg Südwest  52.534996  13.417579
# 3  Tempelhof - Schöneberg           Schöneberg-Nord  52.498855  13.349065
# 4                  Pankow            Helmholtzplatz  52.543157  13.415091
#
# ...

# %% [markdown]
# Let's learn the various methods to grab data from a DataFrame

# %%
df.dtypes
# Out:
# id                                  int64
# name                               object
# host_id                             int64
# host_name                          object
# neighbourhood_group                object
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                               int64
# minimum_nights                      int64
# number_of_reviews                   int64
# last_review                        object
# reviews_per_month                 float64
# calculated_host_listings_count      int64
# availability_365                    int64
# dtype: object

# %%
df['neighbourhood_group']
# Out:
# 0                         Mitte
# 1                        Pankow
# 2                        Pankow
# 3        Tempelhof - Schöneberg
# 4                        Pankow
#                   ...
# 22547                     Mitte
# 22548    Tempelhof - Schöneberg
# 22549                    Pankow
# 22550                     Mitte
# 22551                  Neukölln
# Name: neighbourhood_group, Length: 22552, dtype: object

# %%
df[['host_name', 'availability_365']]
# Out:
#         host_name  availability_365
# 0             Ian               141
# 1         Michael                 0
# 2          Britta               220
# 3            Jana               297
# 4          Bright                26
# ...           ...               ...
# 22547     Ulisses               314
# 22548        Jörg                78
# 22549      Martin                15
# 22550  Arte Luise                 6
# 22551   Sebastian                21
#
# [22552 rows x 2 columns]

# %% [markdown]
# Removing features or variables that you dont want

# %%
del df['latitude']
del df['longitude']

# %%
df.head(10)
# Out:
#       id                                              name  host_id  \
# 0   2015  Berlin-Mitte Value! Quiet courtyard/very central     2217
# 1   2695                Prenzlauer Berg close to Mauerpark     2986
# 2   3176                   Fabulous Flat in great Location     3718
# 3   3309                 BerlinSpot Schöneberg near KaDeWe     4108
# 4   7071                  BrightRoom with sunny greenview!    17391
# 5   9991               Geourgeous flat - outstanding views    33852
# 6  14325                      Apartment in Prenzlauer Berg    55531
# 7  16401                                 APARTMENT TO RENT    59666
# 8  16644                In the Heart of Berlin - Kreuzberg    64696
# 9  17409                Downtown Above The Roofs In Berlin    67590
#
#         host_name       neighbourhood_group             neighbourhood  \
# 0             Ian                     Mitte           Brunnenstr. Süd
# 1         Michael                    Pankow  Prenzlauer Berg Nordwest
# ...

# %% [markdown]
# Creating a new feature (adding a new column)

# %%
df['profit'] = df['price'] + df['minimum_nights']
df.head(7)
# Out:
#       id                                              name  host_id  \
# 0   2015  Berlin-Mitte Value! Quiet courtyard/very central     2217
# 1   2695                Prenzlauer Berg close to Mauerpark     2986
# 2   3176                   Fabulous Flat in great Location     3718
# 3   3309                 BerlinSpot Schöneberg near KaDeWe     4108
# 4   7071                  BrightRoom with sunny greenview!    17391
# 5   9991               Geourgeous flat - outstanding views    33852
# 6  14325                      Apartment in Prenzlauer Berg    55531
#
#         host_name     neighbourhood_group             neighbourhood  \
# 0             Ian                   Mitte           Brunnenstr. Süd
# 1         Michael                  Pankow  Prenzlauer Berg Nordwest
# 2          Britta                  Pankow   Prenzlauer Berg Südwest
# 3            Jana  Tempelhof - Schöneberg           Schöneberg-Nord
# 4          Bright                  Pankow            Helmholtzplatz
# ...

# %% [markdown]
# Drop a column
# axis=0 - refers to rows
# axis=1 - refers to columns

# %%
df.drop('profit', axis=1, inplace=True)

# %%
df
# Out:
#              id                                               name    host_id  \
# 0          2015   Berlin-Mitte Value! Quiet courtyard/very central       2217
# 1          2695                 Prenzlauer Berg close to Mauerpark       2986
# 2          3176                    Fabulous Flat in great Location       3718
# 3          3309                  BerlinSpot Schöneberg near KaDeWe       4108
# 4          7071                   BrightRoom with sunny greenview!      17391
# ...         ...                                                ...        ...
# 22547  29856708       Cozy Apartment right in the center of Berlin   87555909
# 22548  29857108             Altbau/ Schöneberger Kiez / Schlafsofa   67537363
# 22549  29864272   Artists loft with garden in the center of Berlin    3146923
# 22550  29866805              Room for two with private shower / WC   36961901
# 22551  29867352  Sunny, modern and cozy flat in Berlin Neukölln :)  177464875
#
# ...

# %% [markdown]
# Drop a specific row say 2

# %%
df.drop([2],axis=0)
# Out:
#              id                                               name    host_id  \
# 0          2015   Berlin-Mitte Value! Quiet courtyard/very central       2217
# 1          2695                 Prenzlauer Berg close to Mauerpark       2986
# 3          3309                  BerlinSpot Schöneberg near KaDeWe       4108
# 4          7071                   BrightRoom with sunny greenview!      17391
# 5          9991                Geourgeous flat - outstanding views      33852
# ...         ...                                                ...        ...
# 22547  29856708       Cozy Apartment right in the center of Berlin   87555909
# 22548  29857108             Altbau/ Schöneberger Kiez / Schlafsofa   67537363
# 22549  29864272   Artists loft with garden in the center of Berlin    3146923
# 22550  29866805              Room for two with private shower / WC   36961901
# 22551  29867352  Sunny, modern and cozy flat in Berlin Neukölln :)  177464875
#
# ...

# %% [markdown]
# Selecting a row

# %%
df.loc[[1]]
# Out:
#      id                                name  host_id host_name  \
# 1  2695  Prenzlauer Berg close to Mauerpark     2986   Michael
#
#   neighbourhood_group             neighbourhood     room_type  price  \
# 1              Pankow  Prenzlauer Berg Nordwest  Private room     17
#
#    minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 1               2                  6  2018-10-01               1.42
#
#    calculated_host_listings_count  availability_365
# 1                               1                 0

# %%
df.loc[1,'id']
# Out:
# 2695

# %%
df.iloc[[1]]
# Out:
#      id                                name  host_id host_name  \
# 1  2695  Prenzlauer Berg close to Mauerpark     2986   Michael
#
#   neighbourhood_group             neighbourhood     room_type  price  \
# 1              Pankow  Prenzlauer Berg Nordwest  Private room     17
#
#    minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 1               2                  6  2018-10-01               1.42
#
#    calculated_host_listings_count  availability_365
# 1                               1                 0

# %%
df.iloc[[1,2],[0,1]]
# Out:
#      id                                name
# 1  2695  Prenzlauer Berg close to Mauerpark
# 2  3176     Fabulous Flat in great Location

# %%
df.iloc[1]
# Out:
# id                                                              2695
# name                              Prenzlauer Berg close to Mauerpark
# host_id                                                         2986
# host_name                                                    Michael
# neighbourhood_group                                           Pankow
# neighbourhood                               Prenzlauer Berg Nordwest
# room_type                                               Private room
# price                                                             17
# minimum_nights                                                     2
# number_of_reviews                                                  6
# last_review                                               2018-10-01
# reviews_per_month                                               1.42
# calculated_host_listings_count                                     1
# availability_365                                                   0
# ...

# %% [markdown]
# Selecting a subset

# %%
df.loc[[2,3], 'price']
# Out:
# 2    90
# 3    26
# Name: price, dtype: int64

# %%
df.iloc[[1,2], 7]
# Out:
# 1    17
# 2    90
# Name: price, dtype: int64

# %%
df.iloc[[1,2]]['price']
# Out:
# 1    17
# 2    90
# Name: price, dtype: int64

# %%
df.loc[1, 'price']
# Out:
# 17

# %%
df.iloc[[1],7]
# Out:
# 1    17
# Name: price, dtype: int64

# %% [markdown]
# Dealing with missing values

# %%
df.isnull().sum()
# Out:
# id                                   0
# name                                59
# host_id                              0
# host_name                           26
# neighbourhood_group                  0
# neighbourhood                        0
# room_type                            0
# price                                0
# minimum_nights                       0
# number_of_reviews                    0
# last_review                       3908
# reviews_per_month                 3914
# calculated_host_listings_count       0
# availability_365                     0
# dtype: int64

# %% [markdown]
# By looking at a raw number it may not be sufficient. What is more helpful is looking at a ratio or percentage

# %%
100* df.isnull().sum() / len(df)
# Out:
# id                                 0.000000
# name                               0.261618
# host_id                            0.000000
# host_name                          0.115289
# neighbourhood_group                0.000000
# neighbourhood                      0.000000
# room_type                          0.000000
# price                              0.000000
# minimum_nights                     0.000000
# number_of_reviews                  0.000000
# last_review                       17.328840
# reviews_per_month                 17.355445
# calculated_host_listings_count     0.000000
# availability_365                   0.000000
# dtype: float64

# %% [markdown]
# dropna method automatically removes columns or rows that contain missing values

# %%
df.dropna()
# Out:
#              id                                               name    host_id  \
# 0          2015   Berlin-Mitte Value! Quiet courtyard/very central       2217
# 1          2695                 Prenzlauer Berg close to Mauerpark       2986
# 2          3176                    Fabulous Flat in great Location       3718
# 3          3309                  BerlinSpot Schöneberg near KaDeWe       4108
# 4          7071                   BrightRoom with sunny greenview!      17391
# ...         ...                                                ...        ...
# 22449  29772631                 Cosy and lovely room near Ostkreuz   20727291
# 22463  29784461     House on the water HT10 - Heart of East Berlin   22437698
# 22475  29792124                         Welcome to Light Apartment  224133729
# 22508  29817383                                     Prenzlauerberg  224295751
# 22536  29849565  Super zentrales Apartment + Garten für 6 Personen     607481
#
# ...

# %%
df.dropna(axis=1)
# Out:
#              id    host_id     neighbourhood_group             neighbourhood  \
# 0          2015       2217                   Mitte           Brunnenstr. Süd
# 1          2695       2986                  Pankow  Prenzlauer Berg Nordwest
# 2          3176       3718                  Pankow   Prenzlauer Berg Südwest
# 3          3309       4108  Tempelhof - Schöneberg           Schöneberg-Nord
# 4          7071      17391                  Pankow            Helmholtzplatz
# ...         ...        ...                     ...                       ...
# 22547  29856708   87555909                   Mitte           Brunnenstr. Süd
# 22548  29857108   67537363  Tempelhof - Schöneberg           Schöneberg-Nord
# 22549  29864272    3146923                  Pankow   Prenzlauer Berg Südwest
# 22550  29866805   36961901                   Mitte            Alexanderplatz
# 22551  29867352  177464875                Neukölln         Schillerpromenade
#
# ...

# %%
df.isnull().sum()
# Out:
# id                                   0
# name                                59
# host_id                              0
# host_name                           26
# neighbourhood_group                  0
# neighbourhood                        0
# room_type                            0
# price                                0
# minimum_nights                       0
# number_of_reviews                    0
# last_review                       3908
# reviews_per_month                 3914
# calculated_host_listings_count       0
# availability_365                     0
# dtype: int64

# %%
df['reviews_per_month'].fillna((df['reviews_per_month'].mean()), inplace=True)
df
# Out:
#              id                                               name    host_id  \
# 0          2015   Berlin-Mitte Value! Quiet courtyard/very central       2217
# 1          2695                 Prenzlauer Berg close to Mauerpark       2986
# 2          3176                    Fabulous Flat in great Location       3718
# 3          3309                  BerlinSpot Schöneberg near KaDeWe       4108
# 4          7071                   BrightRoom with sunny greenview!      17391
# ...         ...                                                ...        ...
# 22547  29856708       Cozy Apartment right in the center of Berlin   87555909
# 22548  29857108             Altbau/ Schöneberger Kiez / Schlafsofa   67537363
# 22549  29864272   Artists loft with garden in the center of Berlin    3146923
# 22550  29866805              Room for two with private shower / WC   36961901
# 22551  29867352  Sunny, modern and cozy flat in Berlin Neukölln :)  177464875
#
# ...

# %% [markdown]
# removing rows with NaN values, 'name'

# %%
df.head()
# Out:
#      id                                              name  host_id host_name  \
# 0  2015  Berlin-Mitte Value! Quiet courtyard/very central     2217       Ian
# 1  2695                Prenzlauer Berg close to Mauerpark     2986   Michael
# 2  3176                   Fabulous Flat in great Location     3718    Britta
# 3  3309                 BerlinSpot Schöneberg near KaDeWe     4108      Jana
# 4  7071                  BrightRoom with sunny greenview!    17391    Bright
#
#       neighbourhood_group             neighbourhood        room_type  price  \
# 0                   Mitte           Brunnenstr. Süd  Entire home/apt     60
# 1                  Pankow  Prenzlauer Berg Nordwest     Private room     17
# 2                  Pankow   Prenzlauer Berg Südwest  Entire home/apt     90
# 3  Tempelhof - Schöneberg           Schöneberg-Nord     Private room     26
# 4                  Pankow            Helmholtzplatz     Private room     42
#
# ...

# %%
df.dropna(subset=['name'], axis=0, inplace=True)

df.isnull().sum()
# Out:
# id                                   0
# name                                 0
# host_id                              0
# host_name                           26
# neighbourhood_group                  0
# neighbourhood                        0
# room_type                            0
# price                                0
# minimum_nights                       0
# number_of_reviews                    0
# last_review                       3885
# reviews_per_month                    0
# calculated_host_listings_count       0
# availability_365                     0
# dtype: int64

# %%
df.describe()
# Out:
#                  id       host_id         price  minimum_nights  \
# count  2.249300e+04  2.249300e+04  22493.000000    22493.000000
# mean   1.573362e+07  5.408507e+07     66.970480        7.166763
# std    8.553788e+06  5.821806e+07    218.078376       40.717403
# min    2.015000e+03  2.217000e+03      0.000000        1.000000
# 25%    8.087198e+06  9.228021e+06     30.000000        2.000000
# 50%    1.692280e+07  3.123294e+07     45.000000        2.000000
# 75%    2.259922e+07  8.083775e+07     70.000000        4.000000
# max    2.986735e+07  2.245081e+08   9000.000000     5000.000000
#
#        number_of_reviews  reviews_per_month  calculated_host_listings_count  \
# count       22493.000000       22493.000000                    22493.000000
# mean           17.879162           1.137090                        1.920331
# std            36.805939           1.371189                        3.671773
# min             0.000000           0.010000                        1.000000
# ...

# %%
df.cov()
# Out:
# C:\Users\yuyum\AppData\Local\Temp\ipykernel_28396\1545644723.py:1: FutureWarning: The default value of numeric_only in DataFrame.cov is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.cov()
#                                           id       host_id         price  \
# id                              7.316730e+13  2.626595e+14  5.670099e+07
# host_id                         2.626595e+14  3.389342e+15  4.765268e+08
# price                           5.670099e+07  4.765268e+08  4.755818e+04
# minimum_nights                 -1.463175e+07 -6.746983e+07  3.356352e+01
# number_of_reviews              -9.764701e+07 -3.193058e+08 -6.688655e+00
# reviews_per_month               2.633192e+06  1.432919e+07  1.972645e+00
# calculated_host_listings_count  1.188158e+06 -1.042688e+07  5.948858e+01
# availability_365               -6.191545e+07 -6.779264e+07  2.740176e+03
#
# ...

# %%
df.corr()
# Out:
# C:\Users\yuyum\AppData\Local\Temp\ipykernel_28396\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                                       id   host_id     price  minimum_nights  \
# id                              1.000000  0.527445  0.030396       -0.042010
# host_id                         0.527445  1.000000  0.037533       -0.028462
# price                           0.030396  0.037533  1.000000        0.003780
# minimum_nights                 -0.042010 -0.028462  0.003780        1.000000
# number_of_reviews              -0.310158 -0.149015 -0.000833       -0.021783
# reviews_per_month               0.224505  0.179501  0.006597       -0.045799
# calculated_host_listings_count  0.037830 -0.048778  0.074293        0.027240
# ...
